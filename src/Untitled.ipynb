# %%
import torch

print(torch.randint(0, 10, (10,), device="cuda"))

print(torch.randn_like(torch.FloatTensor(3,2)))
# Out:
# tensor([3, 7, 1, 2, 7, 1, 6, 3, 6, 8], device='cuda:0')
# tensor([[ 1.3750,  1.3692],
#         [ 0.8309, -1.1562],
#         [-2.5173,  1.0136]])
